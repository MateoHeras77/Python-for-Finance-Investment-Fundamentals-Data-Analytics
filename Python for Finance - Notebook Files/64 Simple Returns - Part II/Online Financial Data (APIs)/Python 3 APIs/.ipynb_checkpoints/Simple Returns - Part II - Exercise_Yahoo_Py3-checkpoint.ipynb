# %% [markdown]
# ## Simple Returns - Part II

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
MSFT = wb.DataReader('MSFT', data_source='yahoo', start='2000-1-1')
MSFT['simple_return'] = (MSFT['Adj Close'] / MSFT['Adj Close'].shift(1)) - 1
MSFT['simple_return'].head()
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.033781
# 2000-01-05    0.010544
# 2000-01-06   -0.033498
# 2000-01-07    0.013068
# Name: simple_return, dtype: float64

# %% [markdown]
# Plot the simple returns on a graph.

# %%
MSFT['simple_return'].plot(figsize=(17,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Calculate the average daily return.

# %%
MSFT['simple_return'].mean()
# Out:
# 0.0005396700179735364

# %% [markdown]
# Estimate the average annual return.

# %%
round(MSFT['simple_return'].mean() * 250,5)
# Out:
# 0.13492

# %% [markdown]
# Print the percentage version of the result as a float with 2 digits after the decimal point.

# %%
print (str(round(MSFT['simple_return'].mean() * 250,5)*100)+"%")
# Out:
# 13.492%
